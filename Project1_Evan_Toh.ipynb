# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#still need to update***

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat = pd.read_csv('/Users/evan/documents/classes-students/projects1234/project_1/data/sat_2017.csv')
act = pd.read_csv('/Users/evan/documents/classes-students/projects1234/project_1/data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
act
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: The data provided is based on the college admissions entrance exams ACT and SAT. Both sets of data show the participation rate differentiated by state as well as the mean scores for each category of the exam. Based on the mean scores for each category, an average score based on state is derived.
#
# (What other ways i can use to describe??)

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: There are 50 states in the US excluding District of Columbia and Puerto Rico. Since both datasets include District of Columbia and have 51 entries, Puerto Rico's data is excluded. SAT dataset is missing a row containing the national average scores.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: The last row of the ACT dataset contains a non-integer value 'x'. Values for Maryland test results are also missing a digit for both the ACT and SAT. The average SAT score for math should be 524 as found from the source [https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/] and the average ACT score for the subtest science should be 23.2 as found from the source [https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows]
# Minimum/maximum possible value for each subtest:
# - ACT
# -- 4 categories english, mathematics, reading and science with 75, 60, 40 and 40 questions respectively. Each subtest has a score of minimum 1 and maximum of 36. It is important to note that raw scores for each category are converted based on a scaled score (1-36) for the purpose of correcting the slight variations in the difficulty of several versions of the test administered throughout the year. An average composite score is then obtained from the scores of individual subtest.
# - SAT
# -- also 4 categories reading, writing and language, math(no calulator), math(calculator) with 52, 44, 20 and 38 questions respectively. Generally it is classified into 2 sections, reading with writing and language followed by math(calculator/ no calculator) with each section having a minimum/maximum score of 200-800. The scores are derived also from a scale just like in the ACT. This process is called equating that is based on years of student data. The scores are then added to a final score.
#
# (put the top into a table form with some explanation)
#
# Summary of interesting observations from the links provided:
# 1. for ACT, based on the top 3 highest possible average scores obtained, the participation rate for New Hampshire(25.5), Massachusetts(25.4) and Connecticut(25.2) is 18%, 29% and 31% which is fairly low. Because some states implement ACT as a mandatory requirement, it will be useful to look at the highest test scores for states with 100% participation. The top 3 states are Minnesota(21.5), Colorado(20.8) and Wisconsin(20.5). This varies starkly with the states where ACT is not mandatory. Low particpation rates tend to result in higher average test scores. Low participation rate at ACT may suggest a preference for SAT.
#
# 2. for SAT, we tend to observe many more states that have a low participation of below 5%. Highest average SAT scores are achieved by Minnesota, Wisconsin and Iowa where average scores exceed 1270 but with participation below 3%. Recall that Minnesota and Wisconsin have mandatory ACT requirements. Another observation that supports the trend of participation rates being inversely proportional to the test score is lowest average SAT scores found in the states of Delaware, the District of Columbia, Idaho, and Michigan, where the average composite scores were all below 1010. These states have participation rates above 90%. When students do not self select and take the test as part of a requirement, their scores tend to be lower.
#
# 3. SAT is more general knowledge oriented while ACT is more subject oriented which may be better for certain individuals.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code

act.iloc[-1,6] = act.iloc[-1,6].replace('x', '')
#check to see if the error has been changed.
print(act[-1:])
print('\n')

act.iloc[21,5] = 23.2
sat.iloc[20,3] = 524
print(act.iloc[21, 5])
print('\n')
print(sat.iloc[20, 3])
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6      20.2
#
#
# 23.2
#
#
# 524

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
print('ACT test datatypes:')
print(act.dtypes)
print('\n')
print('SAT test datatypes:')
print(sat.dtypes)
# Out:
# ACT test datatypes:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object
#
#
# SAT test datatypes:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
'''
Based on previous cell, we see that the 'Composite' column has an object type, which can mean either there is a mixed
data type or string. So now we check if only the cell that has 20.2x (now removed) causing the entire column to show
an object type of the first value is already a string.
''' 

x = act.iloc[0, 6]
print(x, type(x))
# Out:
# 21.0 <class 'str'>

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: The values under participation and composite should show integer and float respectively.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
#map every row in the series with the function defined above using the syntax found in documentation
updated_series = sat['Participation'].apply(lambda x: float(x.replace('%', '')))
#side notes; map is used for element wise in series, applymap for dataframes and apply for any specified row/columns (loc/iloc)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
#map every row in the series with the function defined above using the syntax found in documentation
sat['Participation'] = sat['Participation'].apply(lambda x: float(x.replace('%', '')))
type(sat.iloc[0,1])
#side notes; map is used for element wise in series, applymap for dataframes and apply for any specified row/columns (loc/iloc)
# Out:
# numpy.float64

# %%
#print to check again because the previous iteration showed this as object
sat['Participation'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
act['Participation'] = act['Participation'].apply(lambda x: float(x.replace('%', '')))
act['Composite'] = act['Composite'].astype(float)
print('Now my datatype for the "Participation" column of act is:', type(act.iloc[0,1]))
print('Now my datatype for the "Composite" column of act is:', type(act.iloc[0,6]))
# Out:
# Now my datatype for the "Participation" column of act is: <class 'numpy.float64'>
# Now my datatype for the "Composite" column of act is: <class 'numpy.float64'>

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
print('ACT test datatypes:')
print(act.dtypes)
print('\n')
print('SAT test datatypes:')
print(sat.dtypes)
# Out:
# ACT test datatypes:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object
#
#
# SAT test datatypes:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
'''
lowercase -> remove spaces and replace with '_' -> unique and informative
use mapping function
'''

sat.columns = sat.columns.map(lambda x: x.replace(' ', '_').lower() + '_sat17')
sat = sat.rename(columns={sat.columns[0]:'state'})
print(sat.columns)
print('\n')
act.columns = act.columns.map(lambda x: x.replace(' ', '_').lower() + '_act17')
act = act.rename(columns={act.columns[0]:'state'})
print(act.columns)
# Out:
# Index(['state', 'participation_sat17',
#        'evidence-based_reading_and_writing_sat17', 'math_sat17',
#        'total_sat17'],
#       dtype='object')
#
#
# Index(['state', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17'],
#       dtype='object')

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|SAT|The State where the data is collected for SAT tests '17|
# |**participation_sat17**|*float*|SAT|The participation rate for the State where the data is collected for SAT tests '17(%)|
# |**evidence-based_reading_and_writing_sat17**|*int*|SAT|SAT score for this section which includes the subtests 'reading' and 'writing and language' in '17|
# |**math_sat17**|*int*|SAT|SAT score for this section includes math(no calculator) and math(calculator) in '17|
# |**total_sat17**|*int*|SAT|Total SAT score which is an addition of the previous 2 sections in '17|
# |**participation_act17**|*float*|ACT|The participation rate for the State where the data is collected for ACT tests '17(%)|
# |**english_act17**|*float*|ACT|ACT score for the subtest 'english' in '17|
# |**math_act17**|*float*|ACT|ACT score for the subtest 'math' in '17|
# |**reading_act17**|*float*|ACT|ACT score for the subtest 'reading' in '17|
# |**science_act17**|*float*|ACT|ACT score for the subtest 'science' in '17|
# |**composite_act17**|*float*|ACT|Combined ACT score derived by taking an average for the 4 individual subtests in '17|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code, removal of extra row
act = act.drop(act.index[0])
act.head()
# Out:
#         state  participation_act17  english_act17  math_act17  reading_act17  \
# 1     Alabama                100.0           18.9        18.4           19.7
# 2      Alaska                 65.0           18.7        19.8           20.4
# 3     Arizona                 62.0           18.6        19.8           20.1
# 4    Arkansas                100.0           18.9        19.0           19.7
# 5  California                 31.0           22.5        22.7           23.1
#
#    science_act17  composite_act17
# 1           19.4             19.2
# 2           19.9             19.8
# 3           19.8             19.7
# 4           19.5             19.4
# 5           22.2             22.8

# %%
#checking value of first index
act.index[0]
# Out:
# 1

# %%
#rename all the index values just in case
act = act.rename(index=lambda x: x - 1)
act.head()
# Out:
#         state  participation_act17  english_act17  math_act17  reading_act17  \
# 0     Alabama                100.0           18.9        18.4           19.7
# 1      Alaska                 65.0           18.7        19.8           20.4
# 2     Arizona                 62.0           18.6        19.8           20.1
# 3    Arkansas                100.0           18.9        19.0           19.7
# 4  California                 31.0           22.5        22.7           23.1
#
#    science_act17  composite_act17
# 0           19.4             19.2
# 1           19.9             19.8
# 2           19.8             19.7
# 3           19.5             19.4
# 4           22.2             22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code, merge on state column, the keys have to be the same
merged_doc = act.merge(sat, on="state")
merged_doc.head()
# Out:
#         state  participation_act17  english_act17  math_act17  reading_act17  \
# 0     Alabama                100.0           18.9        18.4           19.7
# 1      Alaska                 65.0           18.7        19.8           20.4
# 2     Arizona                 62.0           18.6        19.8           20.1
# 3    Arkansas                100.0           18.9        19.0           19.7
# 4  California                 31.0           22.5        22.7           23.1
#
#    science_act17  composite_act17  participation_sat17  \
# 0           19.4             19.2                  5.0
# 1           19.9             19.8                 38.0
# 2           19.8             19.7                 30.0
# 3           19.5             19.4                  3.0
# 4           22.2             22.8                 53.0
#
#    evidence-based_reading_and_writing_sat17  math_sat17  total_sat17
# 0                                       593         572         1165
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
merged_doc.to_csv('../combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat_18 = pd.read_csv('/Users/evan/documents/classes-students-work/projects1234/project_1/data/SAT_18.csv')
act_18 = pd.read_csv('/Users/evan/documents/classes-students-work/projects1234/project_1/data/ACT_18.csv')

# %%
sat_18
# Out:
#                    State Participation Rate  EBRW  Math  Total
# 0                Alabama                 6%   595   571   1166
# 1                 Alaska                43%   562   544   1106
# 2                Arizona                29%   577   572   1149
# 3               Arkansas                 5%   592   576   1169
# 4             California                60%   540   536   1076
# 5               Colorado               100%   519   506   1025
# 6            Connecticut               100%   535   519   1053
# 7               Delaware               100%   505   492    998
# 8   District of Columbia                92%   497   480    977
# 9                Florida                97%   522   493   1014
# 10               Georgia                70%   542   522   1064
# 11                Hawaii                56%   550   549   1099
# 12                 Idaho               100%   508   493   1001
# 13              Illinois                99%   513   506   1019
# ...

# %%
act_18
# Out:
#                    State Percentage of Students Tested  \
# 0                Alabama                           100
# 1                 Alaska                            33
# 2                Arizona                            66
# 3               Arkansas                           100
# 4             California                            27
# 5               Colorado                            30
# 6            Connecticut                            26
# 7               Delaware                            17
# 8   District of Columbia                            32
# 9                Florida                            66
# 10               Georgia                            53
# 11                Hawaii                            89
# 12                 Idaho                            36
# 13              Illinois                            43
# 14               Indiana                            32
# 15                  Iowa                            68
# ...

# %% [markdown]
# Notes: there are 2 more entries for sat, for Puerto Rico and Virgin Islands, remove them because originally we also dont have. Some values are not given, find them manually and update. Check the data types to ensure no problem.

# %%
#Lets start with SAT_18 data first, since they have their own issues we will correct the errors for SAT first then go to ACT
#On first glance, we see a '-', if we use a null test it will not filter this observation. Hence we will remove this manually.
sat_18.drop([39, 47], inplace=True)

# %%
#Puerto Rico's data is no longer included
sat_18.iloc[39]
# Out:
# State                 Rhode Island
# Participation Rate             97%
# EBRW                           513
# Math                           505
# Total                         1018
# Name: 40, dtype: object

# %%
#Virgin Island's data is no longer included
sat_18.iloc[46]
# Out:
# State                 Virginia
# Participation Rate         68%
# EBRW                       567
# Math                       550
# Total                     1117
# Name: 48, dtype: object

# %%
#we will check the datatypes now
sat_18.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
#We will now change the participation rate to a float and convert it to an integer
sat_18['Participation Rate'] = sat_18['Participation Rate'].apply(lambda x: float(x.replace('%', '')))

# %%
#Check the datatypes again
sat_18.dtypes
# Out:
# State                  object
# Participation Rate    float64
# EBRW                    int64
# Math                    int64
# Total                   int64
# dtype: object

# %%
#we are done with SAT tests for now and will move on to ACT tests. First there are a few missing values, we will cross
#reference this manually to available reports and update accordingly.
act_18.iloc[18, 1] = 100
act_18.iloc[33, 1] = 100
act_18.iloc[36, 1] = 100
act_18.iloc[38, 1] = 20
print(act_18.iloc[18, 1])
print(act_18.iloc[33, 1])
print(act_18.iloc[36, 1])
print(act_18.iloc[38, 1])
# Out:
# 100
# 100
# 100
# 20

# %%
#we have updated and checkd out values so now we check the datatypes once again
act_18.dtypes
# Out:
# State                             object
# Percentage of Students Tested     object
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
#even though it looks to be an integer for the percentage of students tested, it is an object. Lets convert it to float now.
act_18['Percentage of Students Tested'] = act_18['Percentage of Students Tested'].apply(lambda x: float(x))

# %%
#Check the data types again
act_18.dtypes
# Out:
# State                             object
# Percentage of Students Tested    float64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
#we notice that some of the column names are slightly different, for the sake of easier comparison, we shall
#change them to be equivalent
sat_18 = sat_18.rename(columns={sat_18.columns[0]:'state'})
sat_18 = sat_18.rename(columns={sat_18.columns[1]:'participation_sat18'})
sat_18 = sat_18.rename(columns={sat_18.columns[2]:'evidence-based_reading_and_writing_sat18'})
sat_18 = sat_18.rename(columns={sat_18.columns[3]:'math_sat18'})
sat_18 = sat_18.rename(columns={sat_18.columns[4]:'total_sat18'})
print(sat_18.columns)
print('\n')
act_18 = act_18.rename(columns={act_18.columns[0]:'state'})
act_18 = act_18.rename(columns={act_18.columns[1]:'participation_act18'})
act_18 = act_18.rename(columns={act_18.columns[2]:'english_act18'})
act_18 = act_18.rename(columns={act_18.columns[3]:'math_act18'})
act_18 = act_18.rename(columns={act_18.columns[4]:'reading_act18'})
act_18 = act_18.rename(columns={act_18.columns[5]:'science_act18'})
act_18 = act_18.rename(columns={act_18.columns[6]:'composite_act18'})
print(act_18.columns)
# Out:
# Index(['state', 'participation_sat18',
#        'evidence-based_reading_and_writing_sat18', 'math_sat18',
#        'total_sat18'],
#       dtype='object')
#
#
# Index(['state', 'participation_act18', 'english_act18', 'math_act18',
#        'reading_act18', 'science_act18', 'composite_act18'],
#       dtype='object')

# %%
#now we have all the column names in the right format, it is time to merge them together.

# %%
merged_doc_18 = act_18.merge(sat_18, on="state")
merged_doc_18.head()
# Out:
#         state  participation_act18  english_act18  math_act18  reading_act18  \
# 0     Alabama                100.0           19.1        18.9           18.3
# 1      Alaska                 33.0           20.8        19.8           20.6
# 2     Arizona                 66.0           19.2        18.2           19.4
# 3    Arkansas                100.0           19.4        19.1           18.9
# 4  California                 27.0           22.7        22.5           22.5
#
#    science_act18  composite_act18  participation_sat18  \
# 0           19.6             19.0                  6.0
# 1           21.6             20.7                 43.0
# 2           19.5             19.2                 29.0
# 3           19.7             19.4                  5.0
# 4           23.0             22.1                 60.0
#
#    evidence-based_reading_and_writing_sat18  math_sat18  total_sat18
# 0                                       595         571         1166
# ...

# %%
merged_doc_18.to_csv('/Users/evan/documents/classes-students-work/projects1234/project_1/combined_2018.csv')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
combined_17 = pd.read_csv('/Users/evan/documents/classes-students-work/projects1234/project_1/combined_2017.csv')
combined_18 = pd.read_csv('/Users/evan/documents/classes-students-work/projects1234/project_1/combined_2018.csv')
merged_final = merged_doc.merge(merged_doc_18, how = 'outer', on='state')

# %%
merged_final[['state', 'participation_act17', 'participation_act18', 'participation_sat17', 'participation_sat18']]
# Out:
#                    state  participation_act17  participation_act18  \
# 0                Alabama                100.0                100.0
# 1                 Alaska                 65.0                 33.0
# 2                Arizona                 62.0                 66.0
# 3               Arkansas                100.0                100.0
# 4             California                 31.0                 27.0
# 5               Colorado                100.0                 30.0
# 6            Connecticut                 31.0                 26.0
# 7               Delaware                 18.0                 17.0
# 8   District of Columbia                 32.0                 32.0
# 9                Florida                 73.0                 66.0
# 10               Georgia                 55.0                 53.0
# 11                Hawaii                 90.0                 89.0
# 12                 Idaho                 38.0                 36.0
# ...

# %%
merged_final.head()
# Out:
#         state  participation_act17  english_act17  math_act17  reading_act17  \
# 0     Alabama                100.0           18.9        18.4           19.7
# 1      Alaska                 65.0           18.7        19.8           20.4
# 2     Arizona                 62.0           18.6        19.8           20.1
# 3    Arkansas                100.0           18.9        19.0           19.7
# 4  California                 31.0           22.5        22.7           23.1
#
#    science_act17  composite_act17  participation_sat17  \
# 0           19.4             19.2                  5.0
# 1           19.9             19.8                 38.0
# 2           19.8             19.7                 30.0
# 3           19.5             19.4                  3.0
# 4           22.2             22.8                 53.0
#
#    evidence-based_reading_and_writing_sat17  math_sat17  ...  \
# 0                                       593         572  ...
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code: getting a quick overview
merged_final.describe().transpose
# Out:
# <bound method DataFrame.transpose of        participation_act17  english_act17  math_act17  reading_act17  \
# count            51.000000      51.000000   51.000000      51.000000
# mean             65.254902      20.931373   21.182353      22.013725
# std              32.140842       2.353677    1.981989       2.067271
# min               8.000000      16.300000   18.000000      18.100000
# 25%              31.000000      19.000000   19.400000      20.450000
# 50%              69.000000      20.700000   20.900000      21.800000
# 75%             100.000000      23.300000   23.100000      24.150000
# max             100.000000      25.500000   25.300000      26.000000
#
#        science_act17  composite_act17  participation_sat17  \
# count      51.000000        51.000000            51.000000
# mean       21.450980        21.519608            39.803922
# std         1.739353         2.020695            35.276632
# min        18.200000        17.800000             2.000000
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def stdev(data_series): #modify to compute all numbers and ignore strings
    return  (1/ len(data_series) * sum([((a - data_series.mean()) ** 2) for a in data_series]))** 0.5

stdev(merged_final['math_act18'])
# Out:
# 2.4222536143202795

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
merged_final.columns
# Out:
# Index(['state', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17',
#        'participation_sat17', 'evidence-based_reading_and_writing_sat17',
#        'math_sat17', 'total_sat17', 'participation_act18', 'english_act18',
#        'math_act18', 'reading_act18', 'science_act18', 'composite_act18',
#        'participation_sat18', 'evidence-based_reading_and_writing_sat18',
#        'math_sat18', 'total_sat18'],
#       dtype='object')

# %%
#Code:
sd = {col.name:stdev(col) for col in [merged_final[i] for i in merged_final.columns if (merged_final[i].dtype=='float64') or (merged_final[i].dtype=='int64')]}
sd
# Out:
# {'participation_act17': 31.824175751231806,
#  'english_act17': 2.3304876369363363,
#  'math_act17': 1.9624620273436781,
#  'reading_act17': 2.0469029314842646,
#  'science_act17': 1.7222161451443676,
#  'composite_act17': 2.000786081581989,
#  'participation_sat17': 34.92907076664508,
#  'evidence-based_reading_and_writing_sat17': 45.21697020437866,
#  'math_sat17': 46.65713364485503,
#  'total_sat17': 91.58351056778743,
#  'participation_act18': 33.745194881997506,
#  'english_act18': 2.0855261815801147,
#  'math_act18': 2.4222536143202795,
#  'reading_act18': 2.015707255555717,
#  'science_act18': 2.145891884510421,
#  'composite_act18': 1.8516885484833543,
#  'participation_sat18': 37.63965409204986,
#  'evidence-based_reading_and_writing_sat18': 44.87118561762388,
#  'math_sat18': 48.72908417723463,
#  'total_sat18': 93.51172603783118}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
sd_np = {col.name:np.std(col) for col in [merged_final[i] for i in merged_final.columns if (merged_final[i].dtype=='float64') or (merged_final[i].dtype=='int64')]}
sd_np
# Out:
# {'participation_act17': 31.824175751231806,
#  'english_act17': 2.3304876369363363,
#  'math_act17': 1.9624620273436781,
#  'reading_act17': 2.0469029314842646,
#  'science_act17': 1.7222161451443676,
#  'composite_act17': 2.000786081581989,
#  'participation_sat17': 34.92907076664508,
#  'evidence-based_reading_and_writing_sat17': 45.21697020437866,
#  'math_sat17': 46.65713364485503,
#  'total_sat17': 91.58351056778743,
#  'participation_act18': 33.745194881997506,
#  'english_act18': 2.0855261815801147,
#  'math_act18': 2.4222536143202795,
#  'reading_act18': 2.015707255555717,
#  'science_act18': 2.145891884510421,
#  'composite_act18': 1.8516885484833543,
#  'participation_sat18': 37.63965409204986,
#  'evidence-based_reading_and_writing_sat18': 44.87118561762388,
#  'math_sat18': 48.72908417723463,
#  'total_sat18': 93.51172603783118}

# %% [markdown]
# Slight deviations from the standard deviations between the manual function and output from pandas describe but the values are exactly the same for the manual function and the numpy.std function.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
merged_final.head()
# Out:
#         state  participation_act17  english_act17  math_act17  reading_act17  \
# 0     Alabama                100.0           18.9        18.4           19.7
# 1      Alaska                 65.0           18.7        19.8           20.4
# 2     Arizona                 62.0           18.6        19.8           20.1
# 3    Arkansas                100.0           18.9        19.0           19.7
# 4  California                 31.0           22.5        22.7           23.1
#
#    science_act17  composite_act17  participation_sat17  \
# 0           19.4             19.2                  5.0
# 1           19.9             19.8                 38.0
# 2           19.8             19.7                 30.0
# 3           19.5             19.4                  3.0
# 4           22.2             22.8                 53.0
#
#    evidence-based_reading_and_writing_sat17  math_sat17  ...  \
# 0                                       593         572  ...
# ...

# %%
#code: find states with highest and lowest participation rates for each test each year. On hindsight easier way to do this is to just use
#df.sort_values(by=[column], ascending=True) and def a function using this. Under the function, only show the columns
#that you want.
print('''ACT '17: States with highest participation rates''')
print(merged_final[(merged_final['participation_act17'] == 100.0)]['state'].tolist())
print('\n')
print('''ACT '17: States with lowest participation rates''')
print(merged_final.iloc[merged_final['participation_act17'].idxmin()]['state'], merged_final['participation_act17'].min())
print('\n')
print('''SAT '17: States with highest participation rates''')
print(merged_final[(merged_final['participation_sat17'] == 100.0)]['state'].tolist())
print('\n')
print('''SAT '17: States with lowest participation rates''')
print(merged_final[merged_final['participation_sat17'] == merged_final['participation_sat17'].min()]['state'].tolist() , merged_final['participation_sat17'].min())
print('\n')
print('''ACT '18: States with highest participation rates''')
print(merged_final[(merged_final['participation_act18'] == 100.0)]['state'].tolist())
print('\n')
print('''ACT '18: States with lowest participation rates''')
print(merged_final.iloc[merged_final['participation_act18'].idxmin()]['state'], merged_final['participation_act18'].min())
print('\n')
print('''SAT '18: States with highest participation rates''')
print(merged_final[(merged_final['participation_sat18'] == 100.0)]['state'].tolist())
print('\n')
print('''SAT '18: States with lowest participation rates''')
print(merged_final[merged_final['participation_sat18'] == merged_final['participation_sat18'].min()]['state'].tolist() , merged_final['participation_sat18'].min())
# Out:
# ACT '17: States with highest participation rates
# ['Alabama', 'Arkansas', 'Colorado', 'Kentucky', 'Louisiana', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nevada', 'North Carolina', 'Oklahoma', 'South Carolina', 'Tennessee', 'Utah', 'Wisconsin', 'Wyoming']
#
#
# ACT '17: States with lowest participation rates
# Maine 8.0
#
#
# SAT '17: States with highest participation rates
# ['Connecticut', 'Delaware', 'District of Columbia', 'Michigan']
#
#
# SAT '17: States with lowest participation rates
# ['Iowa', 'Mississippi', 'North Dakota'] 2.0
#
#
# ACT '18: States with highest participation rates
# ['Alabama', 'Arkansas', 'Kentucky', 'Louisiana', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'North Carolina', 'Ohio', 'Oklahoma', 'South Carolina', 'Tennessee', 'Utah', 'Wisconsin', 'Wyoming']
#
#
# ACT '18: States with lowest participation rates
# Maine 7.0
#
#
# SAT '18: States with highest participation rates
# ...

# %% [markdown]
# The states that have 100% participation rates for ACT test remain unchanged but for SAT, Colorado and Idaho made it into the list but not DOC. 100% is a special figure because it can mean a mandatory requirement which is significant. Because when it is mandatory, it might lower the average test scores for that state which may affect the admission requirements of local colleges. This relationship of higher participation rates lower average test scores will be looked into throughout this project. States with the lowest SAT participation rates in 2017 have also increase its participation rates.

# %%
#code highest and lowest mean total/composite scores for each test each year. 
print('''ACT '17: States with highest composite scores''')
print(merged_final[merged_final['composite_act17'] == merged_final['composite_act17'].max()]['state'].tolist() , merged_final['composite_act17'].max())
print('\n')
print('''ACT '17: States with lowest composite scores''')
print(merged_final[merged_final['composite_act17'] == merged_final['composite_act17'].min()]['state'].tolist() , merged_final['composite_act17'].min())
print('\n')
print('''SAT '17: States with highest average scores''')
print(merged_final[merged_final['total_sat17'] == merged_final['total_sat17'].max()]['state'].tolist() , merged_final['total_sat17'].max())
print('\n')
print('''SAT '17: States with lowest average scores''')
print(merged_final[merged_final['total_sat17'] == merged_final['total_sat17'].min()]['state'].tolist() , merged_final['total_sat17'].min())
print('\n')
print('''ACT '18: States with highest composite scores''')
print(merged_final[merged_final['composite_act18'] == merged_final['composite_act18'].max()]['state'].tolist() , merged_final['composite_act18'].max())
print('\n')
print('''ACT '18: States with lowest composite scores''')
print(merged_final[merged_final['composite_act18'] == merged_final['composite_act18'].min()]['state'].tolist() , merged_final['composite_act18'].min())
print('\n')
print('''SAT '18: States with highest average scores''')
print(merged_final[merged_final['total_sat18'] == merged_final['total_sat18'].max()]['state'].tolist() , merged_final['total_sat18'].max())
print('\n')
print('''SAT '18: States with lowest average scores''')
print(merged_final[merged_final['total_sat18'] == merged_final['total_sat18'].min()]['state'].tolist() , merged_final['total_sat18'].min())
print('\n')
# Out:
# ACT '17: States with highest composite scores
# ['New Hampshire'] 25.5
#
#
# ACT '17: States with lowest composite scores
# ['Nevada'] 17.8
#
#
# SAT '17: States with highest average scores
# ['Minnesota'] 1295
#
#
# SAT '17: States with lowest average scores
# ['District of Columbia'] 950
#
#
# ACT '18: States with highest composite scores
# ['Connecticut'] 24.9
#
#
# ACT '18: States with lowest composite scores
# ['Nevada'] 17.9
#
#
# SAT '18: States with highest average scores
# ['Minnesota'] 1298
#
#
# SAT '18: States with lowest average scores
# ['District of Columbia'] 977

# %% [markdown]
# DOC no longer has 100% participation rate for SAT test in 2018. Despite having the lowest average score, it managed to improve slightly. This improvement may not be significant given slight deviations of score year on year. Nevada hsa 100% participation for ACT test in both years yet scored the lowest average composite score for both years further strengthening the inverse relationship of participation rate with score. Connecticut has the highest scores for ACT test in 2018 yet also have 100% participation for SAT test. This could be because SAT test is mandatory, so those who wished to differentiate themselves took the ACT test, resulting in higher test scores.

# %%
#code ID states with 100% and find the rate change
'''
steps to do: id states with 100% AND not 100% on either tests then determine the % change
on paper, there are 4 instances to mask:
1. act_17 100% & act_18 !100%
2. act_17 !100% & act_18 100%
3. sat_17 100% & sat_18 !100%
4. sat_17 !100% & sat_18 100%
'''

merged_final[(merged_final['participation_act17'] == 100) & (merged_final['participation_act18'] < 100)]
# Out:
#         state  participation_act17  english_act17  math_act17  reading_act17  \
# 5    Colorado                100.0           20.1        20.3           21.2
# 23  Minnesota                100.0           20.4        21.5           21.8
#
#     science_act17  composite_act17  participation_sat17  \
# 5            20.9             20.8                 11.0
# 23           21.6             21.5                  3.0
#
#     evidence-based_reading_and_writing_sat17  math_sat17  ...  \
# 5                                        606         595  ...
# 23                                       644         651  ...
#
#     participation_act18  english_act18  math_act18  reading_act18  \
# 5                  30.0           23.9        23.9           23.2
# 23                 99.0           21.3        20.2           21.4
#
#     science_act18  composite_act18  participation_sat18  \
# 5            24.4             23.5                100.0
# ...

# %%
change_colorado = (merged_final.iloc[5,11] - 100) / 100
change_colorado
# Out:
# -0.7

# %%
change_minnesota = (merged_final.iloc[23,11] - 100) / 100
change_minnesota
# Out:
# -0.01

# %%
#2. act_17 !100% & act_18 100%
df_3 = merged_final[(merged_final['participation_act17'] < 100) & (merged_final['participation_act18'] == 100)]
df_3[['state', 'participation_sat17', 'participation_sat18', 'participation_act17', 'participation_act18']]
# Out:
#        state  participation_sat17  participation_sat18  participation_act17  \
# 27  Nebraska                  3.0                  3.0                 84.0
# 35      Ohio                 12.0                 18.0                 75.0
#
#     participation_act18
# 27                100.0
# 35                100.0

# %%
change_nebraska = (100 - merged_final.iloc[27,1]) / 100
change_nebraska
# Out:
# 0.16

# %%
change_ohio = change_nebraska = (100 - merged_final.iloc[35,1]) / 100
change_ohio
# Out:
# 0.25

# %%
#3. sat_17 100% & sat_18 !100%
merged_final[(merged_final['participation_sat17'] == 100) & (merged_final['participation_sat18'] < 100)]
# Out:
#                   state  participation_act17  english_act17  math_act17  \
# 8  District of Columbia                 32.0           24.4        23.5
#
#    reading_act17  science_act17  composite_act17  participation_sat17  \
# 8           24.9           23.5             24.2                100.0
#
#    evidence-based_reading_and_writing_sat17  math_sat17  ...  \
# 8                                       482         468  ...
#
#    participation_act18  english_act18  math_act18  reading_act18  \
# 8                 32.0           23.6        23.7           22.7
#
#    science_act18  composite_act18  participation_sat18  \
# 8           24.4             23.0                 92.0
#
#    evidence-based_reading_and_writing_sat18  math_sat18  total_sat18
# 8                                       497         480          977
#
# [1 rows x 21 columns]

# %%
change_doc = (merged_final.iloc[8,17] - 100) / 100
change_doc
# Out:
# -0.08

# %%
#4. sat_17 !100% & sat_18 100%
df_4 = merged_final[(merged_final['participation_sat17'] < 100) & (merged_final['participation_sat18'] == 100)]
df_4[['state', 'participation_sat17', 'participation_sat18', 'participation_act17', 'participation_act18']]
# Out:
#        state  participation_sat17  participation_sat18  participation_act17  \
# 5   Colorado                 11.0                100.0                100.0
# 12     Idaho                 93.0                100.0                 38.0
#
#     participation_act18
# 5                  30.0
# 12                 36.0

# %%
change_colorado1 = (100 - merged_final.iloc[5,7]) / 100
change_colorado1
# Out:
# 0.89

# %%
change_idaho = (100 - merged_final.iloc[12,7]) / 100
change_idaho
# Out:
# 0.07

# %% [markdown]
# We see that Colorado made a drastic switch to taking the SAT in 2018 from ACT in 2017 based on the stats. Ohio and Nebraska showed some drastic increase in taking the ACT test as well at 25% and 16% respectively.

# %%
#code ID states that have >50% participation for both tests in one or both years
'''
Instances:
1. 2017: >50% for both tests
2. 2018: >50% for both tests
3. both years: >50% for both tests (intersecton of 1 and 2)
'''

#Instance 1:
merge1 = merged_final[(merged_final['participation_sat17'] > 50) & (merged_final['participation_act17'] > 50)]
merge1
# Out:
#       state  participation_act17  english_act17  math_act17  reading_act17  \
# 9   Florida                 73.0           19.0        19.4           21.0
# 10  Georgia                 55.0           21.0        20.9           22.0
# 11   Hawaii                 90.0           17.8        19.2           19.2
#
#     science_act17  composite_act17  participation_sat17  \
# 9            19.4             19.8                 83.0
# 10           21.3             21.4                 61.0
# 11           19.3             19.0                 55.0
#
#     evidence-based_reading_and_writing_sat17  math_sat17  ...  \
# 9                                        520         497  ...
# 10                                       535         515  ...
# 11                                       544         541  ...
#
#     participation_act18  english_act18  math_act18  reading_act18  \
# 9                  66.0           19.9        19.2           19.3
# ...

# %%
#Instance 2:
merge2 = merged_final[(merged_final['participation_sat18'] > 50) & (merged_final['participation_act18'] > 50)]
merge2
# Out:
#              state  participation_act17  english_act17  math_act17  \
# 9          Florida                 73.0           19.0        19.4
# 10         Georgia                 55.0           21.0        20.9
# 11          Hawaii                 90.0           17.8        19.2
# 33  North Carolina                100.0           17.8        19.3
# 40  South Carolina                100.0           17.5        18.6
#
#     reading_act17  science_act17  composite_act17  participation_sat17  \
# 9            21.0           19.4             19.8                 83.0
# 10           22.0           21.3             21.4                 61.0
# 11           19.2           19.3             19.0                 55.0
# 33           19.6           19.3             19.1                 49.0
# 40           19.1           18.9             18.7                 50.0
#
#     evidence-based_reading_and_writing_sat17  math_sat17  ...  \
# 9                                        520         497  ...
# ...

# %%
#instance 3:
pd.merge(merge1, merge2, on='state', how='inner')
# Out:
#      state  participation_act17_x  english_act17_x  math_act17_x  \
# 0  Florida                   73.0             19.0          19.4
# 1  Georgia                   55.0             21.0          20.9
# 2   Hawaii                   90.0             17.8          19.2
#
#    reading_act17_x  science_act17_x  composite_act17_x  participation_sat17_x  \
# 0             21.0             19.4               19.8                   83.0
# 1             22.0             21.3               21.4                   61.0
# 2             19.2             19.3               19.0                   55.0
#
#    evidence-based_reading_and_writing_sat17_x  math_sat17_x  ...  \
# 0                                         520           497  ...
# 1                                         535           515  ...
# 2                                         544           541  ...
#
#    participation_act18_y  english_act18_y  math_act18_y  reading_act18_y  \
# ...

# %% [markdown]
# 2017 - 2018: an increase in number of states where participation rate for both tests exceed 50%.
# Florida and Hawaii have a 'preferred' test as we see a much higher percentage of students taking one over the other. Florida is equal for both in 2017 but more preferred SAT in 2018 over ACT. Overall more students took both tests.
# Hawaii prefers ACT over SAT for both years.
# Georgia is equal for both tests in 2017 but see a greater shift to SAT in 2018 (61 -> 70 sat vs a 55 -> 53 act). Overall more students took the test in 2018 in Georgia.
# North and South Carolina mandate the taking of ACT test for both years as seen from the 100% participation but an increase of 52 to 55% in participation rate of SAT test in 2018.
# Based on this mask, we can conclude that there is an increase in participation rate for SAT test and more students took both tests in general in 2018.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize = (20,12))
ax = sns.heatmap(merged_final.corr(), annot=True, annot_kws={"size": 14})
ax.set_title('Correlation ACT/SAT for 2017/2018', fontsize=21, y=1.01);
ax

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, title):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(17,11)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], facecolor='r', alpha=0.75) # feel free to add more settings
        ax[i].set_title(list_of_titles[i], fontsize=15)  
    fig.suptitle(title, fontsize=22)
    # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code
plt.style.use('fivethirtyeight')
title1 = "Comparison of Participation Rates for ACT/SAT tests in 2017/2018"
column_list = ['participation_act17', 'participation_sat17', 'participation_act18', 'participation_sat18']
title_list = ['''Participation rate for ACT '17''', '''Participation rate for SAT '17''', '''Participation rate for ACT '18''', '''Participation rate for SAT '18''']
xlabels_list =[]
subplot_histograms(merged_final, column_list, title_list, xlabels_list, title1)

# %% [markdown]
# In this format, when placed side by side, the ACT test looks like a mirror of the SAT test. This makes sense because the higher the frequency of high participation rates for one test, the lower the frequency of high participation rates for the other. Most students do not take both tests. From these plots, the number of states that mandate ACT tests did not change but for the SAT tests, there are more states that require. Based on visual observation, there appears to a switch away from ACT tests to SAT tests.

# %%
plt.style.use('fivethirtyeight')
title2 = "Comparison of Scores for ACT/SAT tests in 2017/2018"
column_list = ['composite_act17', 'total_sat17', 'composite_act18', 'total_sat18']
title_list = ['''Composite Score for ACT '17''', '''Total Score for SAT '17''', '''Composite Score for ACT '18''', '''Total Score for SAT '18''']
xlabels_list = 'Scores'
subplot_histograms(merged_final, column_list, title_list, xlabels_list, title2)

# %% [markdown]
# Both the ACT scores and SAT scores approximate a normal distribution judging from the shape of the histogram. However they do not resemble each other so the correlation is likely to be low.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
merged_final.columns
# Out:
# Index(['state', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17',
#        'participation_sat17', 'evidence-based_reading_and_writing_sat17',
#        'math_sat17', 'total_sat17', 'participation_act18', 'english_act18',
#        'math_act18', 'reading_act18', 'science_act18', 'composite_act18',
#        'participation_sat18', 'evidence-based_reading_and_writing_sat18',
#        'math_sat18', 'total_sat18'],
#       dtype='object')

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
# Code math_act17 vs math_sat17
plt.style.use('fivethirtyeight')
x,y='math_act17','math_sat17'
sns.set(rc={'figure.figsize':(15,8)})
merged_final.plot(kind='scatter', x=x, y=y, marker='o', color='red')
plt.ylabel('Score(200-800)', fontsize=24)
plt.xlabel('Score(1-36)', fontsize=24)
plt.title('Scatter plot for math_act17 & math_sat17', fontsize=32);

# %% [markdown]
# There is no clear relationship between math scores for SAT and that of ACT test in 2017.

# %%
plt.style.use('fivethirtyeight')
merged_final.plot(kind='scatter', x='reading_act17', y='evidence-based_reading_and_writing_sat17', marker='o', color='red')
plt.ylabel('Score(200-800)', fontsize=24)
plt.xlabel('Score(1-36)', fontsize=24)
plt.title('Scatter plot for reading_act17 & evidence-based_reading_and_writing_sat17', fontsize=32);

# %% [markdown]
# There is no clear relationship between composite scores of ACT 2017 and total scores of SAT 2017.

# %%
merged_final.plot(kind='scatter', x='composite_act17', y='total_sat17', marker='o', color='red')
plt.ylabel('SAT Score(200-800)', fontsize=24)
plt.xlabel('ACT Score(1-36)', fontsize=24)
plt.title('Scatter plot for composite_act17 & total_sat17', fontsize=32);

# %% [markdown]
# There is no clear relationship between composite scores of ACT 2017 and total scores of SAT 2017. Based on the head map the correlation is only -0.45.

# %%
merged_final.plot(kind='scatter', x='total_sat17', y='total_sat18', marker='o', color='red')
plt.ylabel('SAT Score(200-800)', fontsize=24)
plt.xlabel('SAT Score(200-800)', fontsize=24);
plt.title('Scatter plot for total_sat17 & total_sat18', fontsize=32);

# %% [markdown]
# There is a clear positive relationship between the total SAT test scores in 2017 and 2018. Based on the heat map the correlation is 0.92. This makes sense because the test scores are computed based on the individual tests and that the individual tests are given a score based on a range that is likely preset to a bell curve to prevent drastic fluctuations.

# %%
merged_final.plot(kind='scatter', x='composite_act17', y='composite_act18', marker='o', color='red')
plt.ylabel('ACT Score(1-36)', fontsize=24)
plt.xlabel('ACT Score(1-36)', fontsize=24);
plt.title('Scatter plot for composite_act17 & composite_act18', fontsize=18);

# %% [markdown]
# ## There is a clear positive relationship between the total ACT test scores in 2017 and 2018. Based on the heat map the correlation is 0.94. This makes sense because the test scores are computed based on the individual tests and that the individual tests are given a score based on a range that is likely preset to a bell curve to prevent drastic fluctuations.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code
data = merged_final[['participation_act17', 'participation_act18', 'participation_sat17', 'participation_sat18']]
sns.boxplot(data=data).set_title('Box Plot for Participation rates of both ACT/SAT for 17/18', fontsize=32)
sns.set(rc={'figure.figsize':(15,8)})
plt.ylabel('Participation(%)', fontsize=24)
plt.xlabel('ACT/SAT test for 2017/2018', fontsize=24);

# %% [markdown]
# Based on these box plots we can conclude that the participation rate for ACT test in 2017 and 2018 is approximately the same. It seems that more states are mandated to take the ACT test as the 75th percentile is already at 100% as compared to the SAT test. For the box plots of participation rates in the SAT tests, there is a large increase in the participation rates of the 75th percentile of roughly 10%. Based purely on this plot, we can say that in general the amount of people taking the ACT test did not change but in total the number of people taking the SAT test increased, both the median and the 75th percentile. We can also see the bottom 25th percentile and the lowest percentile did not change for both tests each year. This may indicate an overall increase in the number of students who are already taking the ACT test taking another SAT test along with some students having converted from ACT test to the SAT test.

# %%
data1 = merged_final[['english_act17', 'english_act18', 'math_act17', 'math_act18', 'reading_act17', 'reading_act18', 'science_act17', 'science_act18', 'composite_act17', 'composite_act18']]
sns.boxplot(data=data1).set_title('Box Plot for all ACT scores for 17/18', fontsize=32)
sns.set(rc={'figure.figsize':(15,8)})
plt.ylabel('Score(1-36)', fontsize=24)
plt.xlabel('Composite Score and every ACT Component Test', fontsize=24);

# %% [markdown]
# Based the box plot for all ACT scores, we are attempting to compare the scores for the year 2017 with 2018. For every test we can see the median is roughly the same usually deviating less than 1 (<3%) year on year. One observation is that the spread for math test in 2018 is larger than that of the previous year. Overall the data looks okay but this is bearing in mind the raw scores of each component is converted into a score of 1-36 which means that there is a good chance these scores have been adjusted to prevent large fluctuations. The result is that the composite score is approximately the same.

# %%
merged_final.columns
# Out:
# Index(['state', 'participation_act17', 'english_act17', 'math_act17',
#        'reading_act17', 'science_act17', 'composite_act17',
#        'participation_sat17', 'evidence-based_reading_and_writing_sat17',
#        'math_sat17', 'total_sat17', 'participation_act18', 'english_act18',
#        'math_act18', 'reading_act18', 'science_act18', 'composite_act18',
#        'participation_sat18', 'evidence-based_reading_and_writing_sat18',
#        'math_sat18', 'total_sat18'],
#       dtype='object')

# %%
data2 = merged_final[['evidence-based_reading_and_writing_sat17', 'math_sat17', 'total_sat17', 'evidence-based_reading_and_writing_sat18', 'math_sat18', 'total_sat18']]
sns.boxplot(data=data2).set_title('Box Plot for all SAT scores for 17/18', fontsize=32)
sns.set(rc={'figure.figsize':(15,8)})
plt.ylabel('Score per test(200-800)', fontsize=24)
plt.xlabel('Total Score and every SAT Component Test', fontsize=24);

# %% [markdown]
# Based the box plot for all SAT scores, we are attempting to compare the scores for the year 2017 with 2018. For every test we can see the median is roughly the same year on year. Overall the data looks okay but likewise for ACT, this is bearing in mind the raw scores of each component is converted into a score of 200-800 which means that there is a good chance these scores have been adjusted to prevent large fluctuations. The result is that the total score is approximately the same.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers: Based on all the plots as well as a quick glance over the summary statistics of the numeric columns. It can be concluded that the participation rates do not follow a normal distribution. It has a high standard deviation that is caused by mandatory state requirements as well as a choice among students to take one over the other. It is difficult in this case to have any inference other than it having a bimodal distribution. This means that either students are mandated to take the ACT test on one hand then there will be low participation on ACT test likewise for states mandated to take the SAT test, resulting in a bimodal distribution. The standard deviation is huge and the mean is not accurate. All the test scores follow a rather controlled standard deviation of 5-10% of the mean which is understandable to maintain the reliability of the tests year on year. While it should approximate to a normal distribution, it also shows a bimodal distribution where there are students who are more motivated and prepared (likely from independent test takers who are not mandated) as well as those who are unprepared. The risk of modelling a normal distribution for the test scores in either test is that higher performing students will find it harder to get a good score and lower performing students will find it easier to obtain a better grade. Therefore, on the respective official test sites, they do state they get a range of values from 'past' data which likely comes from the bimodal distribution instead of a normal one.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No, the distribution is bimodal and does not follow a normal distribution.

# %%
f, axes = plt.subplots(1, 2, figsize=(10,4))

sns.distplot(merged_final['math_act17'], bins=5, ax=axes[0]);
sns.distplot(merged_final['math_act18'], bins=5, ax=axes[1]);

# %%
f, axes = plt.subplots(1, 2, figsize=(10,4))

sns.distplot(merged_final['reading_act17'], bins=5, ax=axes[0]);
sns.distplot(merged_final['reading_act18'], bins=5, ax=axes[1]);

# %%
f, axes = plt.subplots(1, 2, figsize=(10,4))

sns.distplot(merged_final['participation_act17'], bins=5, ax=axes[0]);
sns.distplot(merged_final['participation_act18'], bins=5, ax=axes[1]);

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: Based on these distributions, it shows that the mean will not be reflective of the true mean because there are 2 different groups of students. One group of prepared students and one group who is not.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: Yes, there is a relationship between SAT and ACT participation rates where the correlation based on the heat map is -0.84. This makes sense for people who wish to swap tests to SAT maybe because of mandatory state requirements or personal choice.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: It is not appropriate because both scores are on a different scale. They show no correlation and they are done mostly by different students. i.e. those who take ACT likely wont take SAT, so despite them likely to show a normal distribution on its own, they cannot be compared value to value without an appropriate conversion scale.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Notes: This section was done solely based on the values that were found from the top section, another section was done to account for other conditions.
#
# Ohio paid for all studnets to take the ACT test in 2018 hence participation rate went up to 100. This is a 25% change.
# source: [https://www.daytondailynews.com/news/historically-low-act-scores-red-flag-for-our-country/djfx9Urp719WyEaMfykyxL/]
#
# Nebraska was state mandated in 2018. It was already high to start with hence only a 16% change.
# source: [https://www.education.ne.gov/assessment/act/]
#
# Colorado also state mandated SAT and highlighted one of the biggest shifts from ACT to SAT tests with a change of 900% (if we look at it from 11% to 100% participation rate)
# source: [https://www.testive.com/colorado-sat-change-2017/]
#
# SAT has more people taking the test as seen from the mean. Despite the box plot showing otherwise, this might be because despite the participation rates for the states taking the ACT test may be lesser populated. The box plot only shows the percentage but the actual proportion depends on the states itself. Hence it is expected that the number of students taking each test is about the same with SAT exceeding the students taking ACT according to this link below.
#
# source: [https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/?noredirect=on&utm_term=.ae7de6e393cf]

# %%
#this section is to attempt to track the states that show the biggest shift in tests, they need not be 100% for
#either tests as found in one of the sections above. First we extract the relevant df columns first.

df_5 = merged_final[['state', 'participation_act17', 'participation_act18', 'participation_sat17', 'participation_sat18']]
df_5.head()
# Out:
#         state  participation_act17  participation_act18  participation_sat17  \
# 0     Alabama                100.0                100.0                  5.0
# 1      Alaska                 65.0                 33.0                 38.0
# 2     Arizona                 62.0                 66.0                 30.0
# 3    Arkansas                100.0                100.0                  3.0
# 4  California                 31.0                 27.0                 53.0
#
#    participation_sat18
# 0                  6.0
# 1                 43.0
# 2                 29.0
# 3                  5.0
# 4                 60.0

# %%
#next we want to find out the relevant participant change from ACT and SAT respectively
df_5['participation_change_ACT'] = abs(df_5['participation_act18'] - df_5['participation_act17'])
df_5['participation_change_SAT'] = abs(df_5['participation_sat18'] - df_5['participation_sat17'])
df_5.head()
# Out:
# /Users/evan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/evan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         state  participation_act17  participation_act18  participation_sat17  \
# 0     Alabama                100.0                100.0                  5.0
# ...

# %%
df_5.sort_values(by='participation_change_SAT', ascending=False).head(3)
# Out:
#            state  participation_act17  participation_act18  \
# 13      Illinois                 93.0                 43.0
# 5       Colorado                100.0                 30.0
# 39  Rhode Island                 21.0                 15.0
#
#     participation_sat17  participation_sat18  participation_change_ACT  \
# 13                  9.0                 99.0                      50.0
# 5                  11.0                100.0                      70.0
# 39                 71.0                 97.0                       6.0
#
#     participation_change_SAT
# 13                      90.0
# 5                       89.0
# 39                      26.0

# %%
df_5.sort_values(by='participation_change_ACT', ascending=False).head(3)
# Out:
#        state  participation_act17  participation_act18  participation_sat17  \
# 5   Colorado                100.0                 30.0                 11.0
# 13  Illinois                 93.0                 43.0                  9.0
# 1     Alaska                 65.0                 33.0                 38.0
#
#     participation_sat18  participation_change_ACT  participation_change_SAT
# 5                 100.0                      70.0                      89.0
# 13                 99.0                      50.0                      90.0
# 1                  43.0                      32.0                       5.0

# %% [markdown]
# Looking at the tables we can filter out Colorado, Illinois, Rhode Island and Alaska. Colorado has been screened out in the above section so we shall focus on the other states.
#
# Illinois replaced the ACT with SAT test, showing an almost double uptake of the SAT test from 50% participation. This was not screened out earlier because it was at 99%.
# source: [https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html]
#
# Rhode Island also mandated the SAT test in 2018 therefore showing a large increase in students taking it. It is useful to note that it is already preferred so the increase is only 26 percentage points.
# source: [https://www.providencejournal.com/news/20181025/with-sat-required-ri-sees-jump-in-participation-decline-in-scores]
#
# The huge drop in ACT test rates in Alaska is due to students not needing to graduate with the requirement to take any test. While this cannot explain the slight rise in SAT test participation, it does explain the drastic drop in ACT tests. Perhaps it was mandated for students who are taking diplomas but not other profile of students where SAT tests is still the preferred test.
# https://www.adn.com/alaska-news/education/2016/06/30/students-no-longer-need-national-tests-to-graduate/

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Key takeaways:
# 1. High participation -> lower average scores. So choose a state that suits personal goals.
# 2. There is no correlation between the tests, and so far without knowing the specifics of each test, there is no 'better' test. As of currently, SAT tests seem to be gaining in popularity.
# 3. The average scores every year will be roughly the same, there is no point aiming for a specific score or prioritizing one section over the other. Practising past year papers help because it gives a good gauge of the score for the current year.
# 4. Since the score shows a bimodal distribution, it pays to be prepared because there is a great chance you will end up above the mean score in your state especially when the participation rate is high.
# 5. If you decide to take another test apart from the one that is mandated, be prepared to work really hard for it and see it as a chance for a good score because the competition is likely to be a lot higher. Otherwise, save the effort for the mandatory test.
#
# Choose a state with lower participation rate and suggest a way to increase participation
# 1. Choose to market the test as having a higher average score as compared to other states, which helps students who would like to use this test score at a state where this test is mandated. For example, ACT mandated states' students take SAT and use SAT score to enter a college in a state that is SAT mandated.
